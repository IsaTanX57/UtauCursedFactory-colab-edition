# %%
from pydub import AudioSegment
import shutil
import sys
import subprocess
import os

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

preview = False

consonants = []
vowels = []
consonantNames = []
vowelNames = []

# In Google Colab, the current working directory is typically /content/.
# No need to change directory with __file__ here.
# os.chdir(os.path.dirname(os.path.realpath(__file__)))

# Clearing the console is not standard practice in Colab notebooks.
# os.system('cls' if os.name == 'nt' else 'clear')

def GetLenght(Input):
    result = subprocess.run(['ffprobe', '-v', 'error', '-show_entries', 'format=duration', '-of', 'default=noprint_wrappers=1:nokey=1', os.getcwd() + os.path.sep + Input], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    return float(result.stdout)

def Crossfade(Audio1, Audio2, Crossfade, OutputName, OutputFormat):
    Sound1 = AudioSegment.from_file(Audio1)
    Sound2 = AudioSegment.from_file(Audio2)
    combined = Sound1.append(Sound2, crossfade=Crossfade)
    combined.export(OutputName, format=OutputFormat)

def transform():
    for consonant in range(len(consonants)):
        for vowel in range(len(vowels)):
            consonantLength = GetLenght(consonants[consonant])
            vowelLength = GetLenght(vowels[vowel])
            crossfadeMS = (min(consonantLength, vowelLength) * 1000) / 2
            Crossfade(consonants[consonant], vowels[vowel], crossfadeMS, f"./result/{consonantNames[consonant]}{vowelNames[vowel]}.wav", "wav")
            print(f"Processed \"{consonantNames[consonant]}{vowelNames[vowel]}\"")
            # winsound.PlaySound is for Windows only and not available in Colab.
            # if preview:
            #     winsound.PlaySound(f"./result/{consonantNames[consonant]}{vowelNames[vowel]}.wav", winsound.SND_ASYNC)

def audioDetect():
    for root, dirs, files in os.walk('.'):
        for filename in files:
            if os.path.splitext(filename)[1] == ".mp3":
                # Remove './' from root path if present, otherwise keep as is
                relative_root = root[2:] if root.startswith('./') else root
                yield [relative_root, os.path.join(root, filename), filename[:len(filename) - 4]]

print("Detecting mp3 audio files...")

for file in audioDetect():
    if file[0] == "consonants":
        consonants.append(file[1])
        consonantNames.append(file[2])
    elif file[0] == "vowels":
        vowels.append(file[1])
        vowelNames.append(file[2])

if os.path.isfile("./vowels/n.mp3"):
    consonants.append("./vowels/n.mp3")
    consonantNames.append("n")

if len(vowels) < 6:
    print(color.RED + "\nThere seems to not be enough .mp3 files in the \"vowels\" folder, did you forget to add the N sound?\n" + color.END)
    if input(color.BOLD + "Without the required audio files you won't be able to make a full minimal voicebank, do you still want to continue? (Y/N) " + color.END) != "Y":
        exit()

input(color.BOLD + f"\nI was able to detect {len(consonants)} consonants and {len(vowels)} vowels, which will output a voicebank consisting of {len(consonants) * len(vowels)} audio files in total. Press Enter to continue" + color.END)

# Preview functionality (winsound) is Windows-specific and not available in Colab.
# if os.name == 'nt':
#    preview = True

print("\n")

if os.path.isdir("result") == False:
    os.mkdir("result")

transform()
print("\nCopying vowels...")
for vowel in vowels:
    shutil.copy(vowel, "./result")
print("\nDone! Your voicebank is in the \"result\" folder, feel free to move it to your Utau installation")
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Detecting mp3 audio files...
#
# I was able to detect 16 consonants and 6 vowels, which will output a voicebank consisting of 96 audio files in total. Press Enter to continue
#
#
# Processed "ki"
# Processed "ku"
# Processed "kn"
# Processed "ke"
# Processed "ko"
# Processed "ka"
# Processed "bi"
# Processed "bu"
# Processed "bn"
# Processed "be"
# Processed "bo"
# Processed "ba"
# Processed "di"
# Processed "du"
# Processed "dn"
# Processed "de"
# Processed "do"
# Processed "da"
# Processed "si"
# Processed "su"
# Processed "sn"
# Processed "se"
# Processed "so"
# Processed "sa"
# Processed "hi"
# Processed "hu"
# Processed "hn"
# Processed "he"
# Processed "ho"
# Processed "ha"
# Processed "li"
# Processed "lu"
# Processed "ln"
# Processed "le"
# Processed "lo"
# Processed "la"
# Processed "ti"
# Processed "tu"
# Processed "tn"
# Processed "te"
# Processed "to"
# Processed "ta"
# Processed "zi"
# Processed "zu"
# Processed "zn"
# Processed "ze"
# Processed "zo"
# Processed "za"
# Processed "chi"
# Processed "chu"
# Processed "chn"
# Processed "che"
# Processed "cho"
# Processed "cha"
# Processed "fi"
# Processed "fu"
# Processed "fn"
# Processed "fe"
# Processed "fo"
# Processed "fa"
# Processed "pi"
# Processed "pu"
# Processed "pn"
# Processed "pe"
# Processed "po"
# Processed "pa"
# Processed "ji"
# Processed "ju"
# Processed "jn"
# Processed "je"
# Processed "jo"
# Processed "ja"
# Processed "ri"
# Processed "ru"
# Processed "rn"
# Processed "re"
# Processed "ro"
# Processed "ra"
# Processed "gi"
# Processed "gu"
# Processed "gn"
# Processed "ge"
# Processed "go"
# Processed "ga"
# Processed "vi"
# Processed "vu"
# Processed "vn"
# Processed "ve"
# Processed "vo"
# Processed "va"
# Processed "ni"
# Processed "nu"
# Processed "nn"
# Processed "ne"
# Processed "no"
# Processed "na"
#
# Copying vowels...
#
# Done! Your voicebank is in the "result" folder, feel free to move it to your Utau installation

# %%
import shutil
import os

# Create a zip archive of the 'result' directory
# The base_name is 'result', which will create 'result.zip'
# The format is 'zip'
# The root_dir is '.' to indicate the current working directory
# The base_dir is 'result' to specify which directory to archive
shutil.make_archive('result', 'zip', root_dir='.', base_dir='result')

print("Folder 'result' has been compacted into 'result.zip'")
# Out:
# Folder 'result' has been compacted into 'result.zip'
